# %%
import generate_datasets as ds
from MNIST_functions import *
import numpy as np
import matplotlib.pyplot as plt

# %%
#Generate permuted and rotated tasks 
permuted_train_loaders, permuted_test_loaders, rotated_train_loaders, rotated_test_loaders = ds.load_datasets(num_tasks_permute=10, num_tasks_rotate=10)

# %%
#Run experiment 2A for permutated MNIST on 3 tasks

epoch_accuracies_SGD, epoch_accuracies_EWC, epoch_accuracies_L2 = run_experiment_2A( permuted_train_loaders[0:3], permuted_test_loaders[0:3])
# Out:
# Learning rate: 0.001, Dropout input: 0.0, Dropout hidden: 0.0, Early stopping: False, Num hidden layers: 2, Width hidden layers: 400, Epochs: 20
# Epoch 1/20, Accuracy on test set 0: 0.9430
# Epoch 2/20, Accuracy on test set 0: 0.9521
# Epoch 3/20, Accuracy on test set 0: 0.9590
# Epoch 4/20, Accuracy on test set 0: 0.9633
# Epoch 5/20, Accuracy on test set 0: 0.9652
# Epoch 6/20, Accuracy on test set 0: 0.9663
# Epoch 7/20, Accuracy on test set 0: 0.9695
# Epoch 8/20, Accuracy on test set 0: 0.9700
# Epoch 9/20, Accuracy on test set 0: 0.9691
# Epoch 10/20, Accuracy on test set 0: 0.9717
# Epoch 11/20, Accuracy on test set 0: 0.9717
# Epoch 12/20, Accuracy on test set 0: 0.9714
# Epoch 13/20, Accuracy on test set 0: 0.9733
# Epoch 14/20, Accuracy on test set 0: 0.9726
# Epoch 15/20, Accuracy on test set 0: 0.9743
# Epoch 16/20, Accuracy on test set 0: 0.9738
# Epoch 17/20, Accuracy on test set 0: 0.9736
# Epoch 18/20, Accuracy on test set 0: 0.9741
# Epoch 19/20, Accuracy on test set 0: 0.9743
# Epoch 20/20, Accuracy on test set 0: 0.9741
#
#
# Epoch 1/20, Accuracy on test set 0: 0.9406
# Epoch 1/20, Accuracy on test set 1: 0.9412
# Epoch 2/20, Accuracy on test set 0: 0.9431
# Epoch 2/20, Accuracy on test set 1: 0.9520
# Epoch 3/20, Accuracy on test set 0: 0.9285
# Epoch 3/20, Accuracy on test set 1: 0.9574
# Epoch 4/20, Accuracy on test set 0: 0.9349
# Epoch 4/20, Accuracy on test set 1: 0.9579
# Epoch 5/20, Accuracy on test set 0: 0.9366
# Epoch 5/20, Accuracy on test set 1: 0.9627
# Epoch 6/20, Accuracy on test set 0: 0.9332
# Epoch 6/20, Accuracy on test set 1: 0.9655
# Epoch 7/20, Accuracy on test set 0: 0.9336
# Epoch 7/20, Accuracy on test set 1: 0.9663
# Epoch 8/20, Accuracy on test set 0: 0.9324
# Epoch 8/20, Accuracy on test set 1: 0.9673
# Epoch 9/20, Accuracy on test set 0: 0.9305
# Epoch 9/20, Accuracy on test set 1: 0.9696
# Epoch 10/20, Accuracy on test set 0: 0.9290
# Epoch 10/20, Accuracy on test set 1: 0.9692
# Epoch 11/20, Accuracy on test set 0: 0.9275
# Epoch 11/20, Accuracy on test set 1: 0.9704
# Epoch 12/20, Accuracy on test set 0: 0.9252
# Epoch 12/20, Accuracy on test set 1: 0.9700
# Epoch 13/20, Accuracy on test set 0: 0.9287
# Epoch 13/20, Accuracy on test set 1: 0.9709
# Epoch 14/20, Accuracy on test set 0: 0.9279
# Epoch 14/20, Accuracy on test set 1: 0.9713
# Epoch 15/20, Accuracy on test set 0: 0.9281
# Epoch 15/20, Accuracy on test set 1: 0.9713
# Epoch 16/20, Accuracy on test set 0: 0.9265
# Epoch 16/20, Accuracy on test set 1: 0.9729
# Epoch 17/20, Accuracy on test set 0: 0.9239
# Epoch 17/20, Accuracy on test set 1: 0.9724
# Epoch 18/20, Accuracy on test set 0: 0.9242
# Epoch 18/20, Accuracy on test set 1: 0.9714
# Epoch 19/20, Accuracy on test set 0: 0.9223
# Epoch 19/20, Accuracy on test set 1: 0.9715
# Epoch 20/20, Accuracy on test set 0: 0.9214
# Epoch 20/20, Accuracy on test set 1: 0.9721
#
#
# Epoch 1/20, Accuracy on test set 0: 0.8322
# Epoch 1/20, Accuracy on test set 1: 0.9474
# Epoch 1/20, Accuracy on test set 2: 0.9408
# Epoch 2/20, Accuracy on test set 0: 0.8160
# Epoch 2/20, Accuracy on test set 1: 0.9389
# Epoch 2/20, Accuracy on test set 2: 0.9563
# Epoch 3/20, Accuracy on test set 0: 0.8240
# Epoch 3/20, Accuracy on test set 1: 0.9386
# Epoch 3/20, Accuracy on test set 2: 0.9579
# Epoch 4/20, Accuracy on test set 0: 0.7981
# Epoch 4/20, Accuracy on test set 1: 0.9313
# Epoch 4/20, Accuracy on test set 2: 0.9618
# Epoch 5/20, Accuracy on test set 0: 0.8051
# Epoch 5/20, Accuracy on test set 1: 0.9341
# Epoch 5/20, Accuracy on test set 2: 0.9653
# Epoch 6/20, Accuracy on test set 0: 0.8046
# Epoch 6/20, Accuracy on test set 1: 0.9288
# Epoch 6/20, Accuracy on test set 2: 0.9674
# Epoch 7/20, Accuracy on test set 0: 0.8047
# Epoch 7/20, Accuracy on test set 1: 0.9325
# Epoch 7/20, Accuracy on test set 2: 0.9686
# Epoch 8/20, Accuracy on test set 0: 0.8105
# Epoch 8/20, Accuracy on test set 1: 0.9325
# Epoch 8/20, Accuracy on test set 2: 0.9701
# Epoch 9/20, Accuracy on test set 0: 0.8027
# Epoch 9/20, Accuracy on test set 1: 0.9330
# Epoch 9/20, Accuracy on test set 2: 0.9687
# Epoch 10/20, Accuracy on test set 0: 0.7974
# Epoch 10/20, Accuracy on test set 1: 0.9288
# Epoch 10/20, Accuracy on test set 2: 0.9720
# Epoch 11/20, Accuracy on test set 0: 0.7955
# Epoch 11/20, Accuracy on test set 1: 0.9283
# Epoch 11/20, Accuracy on test set 2: 0.9710
# Epoch 12/20, Accuracy on test set 0: 0.7945
# Epoch 12/20, Accuracy on test set 1: 0.9288
# Epoch 12/20, Accuracy on test set 2: 0.9712
# Epoch 13/20, Accuracy on test set 0: 0.7960
# Epoch 13/20, Accuracy on test set 1: 0.9269
# Epoch 13/20, Accuracy on test set 2: 0.9723
# Epoch 14/20, Accuracy on test set 0: 0.7971
# Epoch 14/20, Accuracy on test set 1: 0.9275
# Epoch 14/20, Accuracy on test set 2: 0.9724
# Epoch 15/20, Accuracy on test set 0: 0.7976
# Epoch 15/20, Accuracy on test set 1: 0.9270
# Epoch 15/20, Accuracy on test set 2: 0.9723
# Epoch 16/20, Accuracy on test set 0: 0.7962
# Epoch 16/20, Accuracy on test set 1: 0.9271
# Epoch 16/20, Accuracy on test set 2: 0.9729
# Epoch 17/20, Accuracy on test set 0: 0.7918
# Epoch 17/20, Accuracy on test set 1: 0.9241
# Epoch 17/20, Accuracy on test set 2: 0.9728
# Epoch 18/20, Accuracy on test set 0: 0.7930
# Epoch 18/20, Accuracy on test set 1: 0.9255
# Epoch 18/20, Accuracy on test set 2: 0.9737
# Epoch 19/20, Accuracy on test set 0: 0.7932
# Epoch 19/20, Accuracy on test set 1: 0.9259
# Epoch 19/20, Accuracy on test set 2: 0.9731
# Epoch 20/20, Accuracy on test set 0: 0.7897
# Epoch 20/20, Accuracy on test set 1: 0.9233
# Epoch 20/20, Accuracy on test set 2: 0.9734
#
#
# {0: {0: [0.943, 0.9521, 0.959, 0.9633, 0.9652, 0.9663, 0.9695, 0.97, 0.9691, 0.9717, 0.9717, 0.9714, 0.9733, 0.9726, 0.9743, 0.9738, 0.9736, 0.9741, 0.9743, 0.9741]}, 1: {0: [0.9406, 0.9431, 0.9285, 0.9349, 0.9366, 0.9332, 0.9336, 0.9324, 0.9305, 0.929, 0.9275, 0.9252, 0.9287, 0.9279, 0.9281, 0.9265, 0.9239, 0.9242, 0.9223, 0.9214], 1: [0.9412, 0.952, 0.9574, 0.9579, 0.9627, 0.9655, 0.9663, 0.9673, 0.9696, 0.9692, 0.9704, 0.97, 0.9709, 0.9713, 0.9713, 0.9729, 0.9724, 0.9714, 0.9715, 0.9721]}, 2: {0: [0.8322, 0.816, 0.824, 0.7981, 0.8051, 0.8046, 0.8047, 0.8105, 0.8027, 0.7974, 0.7955, 0.7945, 0.796, 0.7971, 0.7976, 0.7962, 0.7918, 0.793, 0.7932, 0.7897], 1: [0.9474, 0.9389, 0.9386, 0.9313, 0.9341, 0.9288, 0.9325, 0.9325, 0.933, 0.9288, 0.9283, 0.9288, 0.9269, 0.9275, 0.927, 0.9271, 0.9241, 0.9255, 0.9259, 0.9233], 2: [0.9408, 0.9563, 0.9579, 0.9618, 0.9653, 0.9674, 0.9686, 0.9701, 0.9687, 0.972, 0.971, 0.9712, 0.9723, 0.9724, 0.9723, 0.9729, 0.9728, 0.9737, 0.9731, 0.9734]}}
# Epoch 1/20, Accuracy on test set 0: 0.9399
# Epoch 2/20, Accuracy on test set 0: 0.9533
# Epoch 3/20, Accuracy on test set 0: 0.9604
# Epoch 4/20, Accuracy on test set 0: 0.9611
# Epoch 5/20, Accuracy on test set 0: 0.9653
# Epoch 6/20, Accuracy on test set 0: 0.9682
# Epoch 7/20, Accuracy on test set 0: 0.9675
# Epoch 8/20, Accuracy on test set 0: 0.9713
# Epoch 9/20, Accuracy on test set 0: 0.9698
# Epoch 10/20, Accuracy on test set 0: 0.9697
# Epoch 11/20, Accuracy on test set 0: 0.9708
# Epoch 12/20, Accuracy on test set 0: 0.9726
# Epoch 13/20, Accuracy on test set 0: 0.9718
# Epoch 14/20, Accuracy on test set 0: 0.9723
# Epoch 15/20, Accuracy on test set 0: 0.9725
# Epoch 16/20, Accuracy on test set 0: 0.9733
# Epoch 17/20, Accuracy on test set 0: 0.9727
# Epoch 18/20, Accuracy on test set 0: 0.9725
# Epoch 19/20, Accuracy on test set 0: 0.9730
# Epoch 20/20, Accuracy on test set 0: 0.9733
#
#
# Epoch 1/20, Accuracy on test set 0: 0.9461
# Epoch 1/20, Accuracy on test set 1: 0.9395
# Epoch 2/20, Accuracy on test set 0: 0.9443
# Epoch 2/20, Accuracy on test set 1: 0.9553
# Epoch 3/20, Accuracy on test set 0: 0.9402
# Epoch 3/20, Accuracy on test set 1: 0.9597
# Epoch 4/20, Accuracy on test set 0: 0.9383
# Epoch 4/20, Accuracy on test set 1: 0.9634
# Epoch 5/20, Accuracy on test set 0: 0.9379
# Epoch 5/20, Accuracy on test set 1: 0.9637
# Epoch 6/20, Accuracy on test set 0: 0.9359
# Epoch 6/20, Accuracy on test set 1: 0.9647
# Epoch 7/20, Accuracy on test set 0: 0.9364
# Epoch 7/20, Accuracy on test set 1: 0.9662
# Epoch 8/20, Accuracy on test set 0: 0.9360
# Epoch 8/20, Accuracy on test set 1: 0.9673
# Epoch 9/20, Accuracy on test set 0: 0.9355
# Epoch 9/20, Accuracy on test set 1: 0.9659
# Epoch 10/20, Accuracy on test set 0: 0.9391
# Epoch 10/20, Accuracy on test set 1: 0.9700
# Epoch 11/20, Accuracy on test set 0: 0.9389
# Epoch 11/20, Accuracy on test set 1: 0.9708
# Epoch 12/20, Accuracy on test set 0: 0.9351
# Epoch 12/20, Accuracy on test set 1: 0.9709
# Epoch 13/20, Accuracy on test set 0: 0.9353
# Epoch 13/20, Accuracy on test set 1: 0.9728
# Epoch 14/20, Accuracy on test set 0: 0.9382
# Epoch 14/20, Accuracy on test set 1: 0.9713
# Epoch 15/20, Accuracy on test set 0: 0.9390
# Epoch 15/20, Accuracy on test set 1: 0.9723
# Epoch 16/20, Accuracy on test set 0: 0.9384
# Epoch 16/20, Accuracy on test set 1: 0.9722
# Epoch 17/20, Accuracy on test set 0: 0.9389
# Epoch 17/20, Accuracy on test set 1: 0.9720
# Epoch 18/20, Accuracy on test set 0: 0.9399
# Epoch 18/20, Accuracy on test set 1: 0.9732
# Epoch 19/20, Accuracy on test set 0: 0.9418
# Epoch 19/20, Accuracy on test set 1: 0.9729
# Epoch 20/20, Accuracy on test set 0: 0.9420
# Epoch 20/20, Accuracy on test set 1: 0.9731
#
#
# Epoch 1/20, Accuracy on test set 0: 0.8747
# Epoch 1/20, Accuracy on test set 1: 0.9358
# Epoch 1/20, Accuracy on test set 2: 0.9444
# Epoch 2/20, Accuracy on test set 0: 0.8651
# Epoch 2/20, Accuracy on test set 1: 0.9257
# Epoch 2/20, Accuracy on test set 2: 0.9548
# Epoch 3/20, Accuracy on test set 0: 0.8772
# Epoch 3/20, Accuracy on test set 1: 0.9319
# Epoch 3/20, Accuracy on test set 2: 0.9606
# Epoch 4/20, Accuracy on test set 0: 0.8737
# Epoch 4/20, Accuracy on test set 1: 0.9205
# Epoch 4/20, Accuracy on test set 2: 0.9635
# Epoch 5/20, Accuracy on test set 0: 0.8649
# Epoch 5/20, Accuracy on test set 1: 0.9219
# Epoch 5/20, Accuracy on test set 2: 0.9634
# Epoch 6/20, Accuracy on test set 0: 0.8716
# Epoch 6/20, Accuracy on test set 1: 0.9219
# Epoch 6/20, Accuracy on test set 2: 0.9676
# Epoch 7/20, Accuracy on test set 0: 0.8750
# Epoch 7/20, Accuracy on test set 1: 0.9183
# Epoch 7/20, Accuracy on test set 2: 0.9687
# Epoch 8/20, Accuracy on test set 0: 0.8698
# Epoch 8/20, Accuracy on test set 1: 0.9182
# Epoch 8/20, Accuracy on test set 2: 0.9692
# Epoch 9/20, Accuracy on test set 0: 0.8739
# Epoch 9/20, Accuracy on test set 1: 0.9176
# Epoch 9/20, Accuracy on test set 2: 0.9695
# Epoch 10/20, Accuracy on test set 0: 0.8726
# Epoch 10/20, Accuracy on test set 1: 0.9166
# Epoch 10/20, Accuracy on test set 2: 0.9700
# Epoch 11/20, Accuracy on test set 0: 0.8787
# Epoch 11/20, Accuracy on test set 1: 0.9189
# Epoch 11/20, Accuracy on test set 2: 0.9710
# Epoch 12/20, Accuracy on test set 0: 0.8749
# Epoch 12/20, Accuracy on test set 1: 0.9224
# Epoch 12/20, Accuracy on test set 2: 0.9713
# Epoch 13/20, Accuracy on test set 0: 0.8723
# Epoch 13/20, Accuracy on test set 1: 0.9170
# Epoch 13/20, Accuracy on test set 2: 0.9717
# Epoch 14/20, Accuracy on test set 0: 0.8754
# Epoch 14/20, Accuracy on test set 1: 0.9178
# Epoch 14/20, Accuracy on test set 2: 0.9728
# Epoch 15/20, Accuracy on test set 0: 0.8741
# Epoch 15/20, Accuracy on test set 1: 0.9183
# Epoch 15/20, Accuracy on test set 2: 0.9713
# Epoch 16/20, Accuracy on test set 0: 0.8761
# Epoch 16/20, Accuracy on test set 1: 0.9184
# Epoch 16/20, Accuracy on test set 2: 0.9726
# Epoch 17/20, Accuracy on test set 0: 0.8747
# Epoch 17/20, Accuracy on test set 1: 0.9198
# Epoch 17/20, Accuracy on test set 2: 0.9729
# Epoch 18/20, Accuracy on test set 0: 0.8778
# Epoch 18/20, Accuracy on test set 1: 0.9184
# Epoch 18/20, Accuracy on test set 2: 0.9731
# Epoch 19/20, Accuracy on test set 0: 0.8760
# Epoch 19/20, Accuracy on test set 1: 0.9205
# Epoch 19/20, Accuracy on test set 2: 0.9739
# Epoch 20/20, Accuracy on test set 0: 0.8728
# Epoch 20/20, Accuracy on test set 1: 0.9254
# Epoch 20/20, Accuracy on test set 2: 0.9726
#
#
# Epoch 1/20, Accuracy on test set 0: 0.9376
# Epoch 2/20, Accuracy on test set 0: 0.9583
# Epoch 3/20, Accuracy on test set 0: 0.9619
# Epoch 4/20, Accuracy on test set 0: 0.9624
# Epoch 5/20, Accuracy on test set 0: 0.9637
# Epoch 6/20, Accuracy on test set 0: 0.9673
# Epoch 7/20, Accuracy on test set 0: 0.9689
# Epoch 8/20, Accuracy on test set 0: 0.9699
# Epoch 9/20, Accuracy on test set 0: 0.9703
# Epoch 10/20, Accuracy on test set 0: 0.9704
# Epoch 11/20, Accuracy on test set 0: 0.9712
# Epoch 12/20, Accuracy on test set 0: 0.9715
# Epoch 13/20, Accuracy on test set 0: 0.9726
# Epoch 14/20, Accuracy on test set 0: 0.9722
# Epoch 15/20, Accuracy on test set 0: 0.9724
# Epoch 16/20, Accuracy on test set 0: 0.9732
# Epoch 17/20, Accuracy on test set 0: 0.9730
# Epoch 18/20, Accuracy on test set 0: 0.9737
# Epoch 19/20, Accuracy on test set 0: 0.9733
# Epoch 20/20, Accuracy on test set 0: 0.9739
#
#
# Epoch 1/20, Accuracy on test set 0: 0.9473
# Epoch 1/20, Accuracy on test set 1: 0.9405
# Epoch 2/20, Accuracy on test set 0: 0.9456
# Epoch 2/20, Accuracy on test set 1: 0.9548
# Epoch 3/20, Accuracy on test set 0: 0.9453
# Epoch 3/20, Accuracy on test set 1: 0.9617
# Epoch 4/20, Accuracy on test set 0: 0.9432
# Epoch 4/20, Accuracy on test set 1: 0.9668
# Epoch 5/20, Accuracy on test set 0: 0.9369
# Epoch 5/20, Accuracy on test set 1: 0.9646
# Epoch 6/20, Accuracy on test set 0: 0.9392
# Epoch 6/20, Accuracy on test set 1: 0.9688
# Epoch 7/20, Accuracy on test set 0: 0.9330
# Epoch 7/20, Accuracy on test set 1: 0.9676
# Epoch 8/20, Accuracy on test set 0: 0.9366
# Epoch 8/20, Accuracy on test set 1: 0.9723
# Epoch 9/20, Accuracy on test set 0: 0.9333
# Epoch 9/20, Accuracy on test set 1: 0.9707
# Epoch 10/20, Accuracy on test set 0: 0.9284
# Epoch 10/20, Accuracy on test set 1: 0.9696
# Epoch 11/20, Accuracy on test set 0: 0.9309
# Epoch 11/20, Accuracy on test set 1: 0.9730
# Epoch 12/20, Accuracy on test set 0: 0.9266
# Epoch 12/20, Accuracy on test set 1: 0.9714
# Epoch 13/20, Accuracy on test set 0: 0.9280
# Epoch 13/20, Accuracy on test set 1: 0.9737
# Epoch 14/20, Accuracy on test set 0: 0.9251
# Epoch 14/20, Accuracy on test set 1: 0.9733
# Epoch 15/20, Accuracy on test set 0: 0.9262
# Epoch 15/20, Accuracy on test set 1: 0.9739
# Epoch 16/20, Accuracy on test set 0: 0.9250
# Epoch 16/20, Accuracy on test set 1: 0.9746
# Epoch 17/20, Accuracy on test set 0: 0.9236
# Epoch 17/20, Accuracy on test set 1: 0.9742
# Epoch 18/20, Accuracy on test set 0: 0.9217
# Epoch 18/20, Accuracy on test set 1: 0.9724
# Epoch 19/20, Accuracy on test set 0: 0.9203
# Epoch 19/20, Accuracy on test set 1: 0.9746
# Epoch 20/20, Accuracy on test set 0: 0.9206
# Epoch 20/20, Accuracy on test set 1: 0.9754
#
#
# Epoch 1/20, Accuracy on test set 0: 0.8444
# Epoch 1/20, Accuracy on test set 1: 0.9494
# Epoch 1/20, Accuracy on test set 2: 0.9463
# Epoch 2/20, Accuracy on test set 0: 0.8298
# Epoch 2/20, Accuracy on test set 1: 0.9431
# Epoch 2/20, Accuracy on test set 2: 0.9578
# Epoch 3/20, Accuracy on test set 0: 0.8401
# Epoch 3/20, Accuracy on test set 1: 0.9365
# Epoch 3/20, Accuracy on test set 2: 0.9606
# Epoch 4/20, Accuracy on test set 0: 0.8286
# Epoch 4/20, Accuracy on test set 1: 0.9397
# Epoch 4/20, Accuracy on test set 2: 0.9667
# Epoch 5/20, Accuracy on test set 0: 0.8159
# Epoch 5/20, Accuracy on test set 1: 0.9355
# Epoch 5/20, Accuracy on test set 2: 0.9662
# Epoch 6/20, Accuracy on test set 0: 0.8141
# Epoch 6/20, Accuracy on test set 1: 0.9340
# Epoch 6/20, Accuracy on test set 2: 0.9678
# Epoch 7/20, Accuracy on test set 0: 0.8175
# Epoch 7/20, Accuracy on test set 1: 0.9304
# Epoch 7/20, Accuracy on test set 2: 0.9695
# Epoch 8/20, Accuracy on test set 0: 0.8182
# Epoch 8/20, Accuracy on test set 1: 0.9283
# Epoch 8/20, Accuracy on test set 2: 0.9699
# Epoch 9/20, Accuracy on test set 0: 0.8092
# Epoch 9/20, Accuracy on test set 1: 0.9233
# Epoch 9/20, Accuracy on test set 2: 0.9695
# Epoch 10/20, Accuracy on test set 0: 0.8045
# Epoch 10/20, Accuracy on test set 1: 0.9249
# Epoch 10/20, Accuracy on test set 2: 0.9701
# Epoch 11/20, Accuracy on test set 0: 0.8035
# Epoch 11/20, Accuracy on test set 1: 0.9242
# Epoch 11/20, Accuracy on test set 2: 0.9710
# Epoch 12/20, Accuracy on test set 0: 0.7957
# Epoch 12/20, Accuracy on test set 1: 0.9247
# Epoch 12/20, Accuracy on test set 2: 0.9726
# Epoch 13/20, Accuracy on test set 0: 0.8024
# Epoch 13/20, Accuracy on test set 1: 0.9201
# Epoch 13/20, Accuracy on test set 2: 0.9724
# Epoch 14/20, Accuracy on test set 0: 0.7965
# Epoch 14/20, Accuracy on test set 1: 0.9204
# Epoch 14/20, Accuracy on test set 2: 0.9737
# Epoch 15/20, Accuracy on test set 0: 0.7953
# Epoch 15/20, Accuracy on test set 1: 0.9192
# Epoch 15/20, Accuracy on test set 2: 0.9735
# Epoch 16/20, Accuracy on test set 0: 0.7960
# Epoch 16/20, Accuracy on test set 1: 0.9190
# Epoch 16/20, Accuracy on test set 2: 0.9735
# Epoch 17/20, Accuracy on test set 0: 0.7914
# Epoch 17/20, Accuracy on test set 1: 0.9176
# Epoch 17/20, Accuracy on test set 2: 0.9733
# Epoch 18/20, Accuracy on test set 0: 0.7911
# Epoch 18/20, Accuracy on test set 1: 0.9166
# Epoch 18/20, Accuracy on test set 2: 0.9744
# Epoch 19/20, Accuracy on test set 0: 0.7895
# Epoch 19/20, Accuracy on test set 1: 0.9167
# Epoch 19/20, Accuracy on test set 2: 0.9751
# Epoch 20/20, Accuracy on test set 0: 0.7887
# Epoch 20/20, Accuracy on test set 1: 0.9159
# Epoch 20/20, Accuracy on test set 2: 0.9744

# %%
#Define function for ploting for 2A
def plot_experiment_2A(epoch_accuracies_SGD, epoch_accuracies_EWC, epoch_accuracies_L2):
    sgd_A = [epoch_accuracies_SGD[0][0], epoch_accuracies_SGD[1][0], epoch_accuracies_SGD[2][0]]
    ewc_A = [epoch_accuracies_EWC[0][0], epoch_accuracies_EWC[1][0], epoch_accuracies_EWC[2][0]]
    l2_A = [epoch_accuracies_L2[0][0], epoch_accuracies_L2[1][0], epoch_accuracies_L2[2][0]]
    
    sgd_B = [epoch_accuracies_SGD[1][1], epoch_accuracies_SGD[2][1]]
    ewc_B = [epoch_accuracies_EWC[1][1], epoch_accuracies_EWC[2][1]]
    l2_B = [epoch_accuracies_L2[1][1], epoch_accuracies_L2[2][1]]
    
    sgd_C = [epoch_accuracies_SGD[2][2]]
    ewc_C = [epoch_accuracies_EWC[2][2]]
    l2_C = [epoch_accuracies_L2[2][2]]
    
    def flatten(lst):
        return [item for sublist in lst for item in sublist]
    
    sgd_A_flat, ewc_A_flat, l2_A_flat = map(flatten, [sgd_A, ewc_A, l2_A])
    sgd_B_flat, ewc_B_flat, l2_B_flat = map(flatten, [sgd_B, ewc_B, l2_B])
    sgd_C_flat, ewc_C_flat, l2_C_flat = map(flatten, [sgd_C, ewc_C, l2_C])
    
    max_len_A = len(sgd_A_flat)
    time_A = np.arange(max_len_A)
    
    max_len_B = len(sgd_B_flat)
    time_B = np.arange(max_len_B)
    
    max_len_C = len(sgd_C_flat)
    time_C = np.arange(max_len_C)
    
    def pad_with_nans(original, max_len):
        return [np.nan] * (max_len - len(original)) + original
    
    sgd_B_padded, ewc_B_padded, l2_B_padded = map(lambda x: pad_with_nans(x, max_len_A), [sgd_B_flat, ewc_B_flat, l2_B_flat])
    sgd_C_padded, ewc_C_padded, l2_C_padded = map(lambda x: pad_with_nans(x, max_len_A), [sgd_C_flat, ewc_C_flat, l2_C_flat])
    
    time_B_padded = np.arange(len(sgd_B_padded))
    time_C_padded = np.arange(len(sgd_C_padded))
    
    fig, axes = plt.subplots(3, 1, figsize=(10, 6), sharex=True)
    colors = {'ewc': 'red', 'l2': 'green', 'sgd': 'blue'}
    
    axes[0].plot(time_A, sgd_A_flat, label="SGD", color=colors['sgd'], alpha=0.8)
    axes[0].plot(time_A, ewc_A_flat, label="EWC", color=colors['ewc'], alpha=0.8)
    axes[0].plot(time_A, l2_A_flat, label="L2", color=colors['l2'], alpha=0.8)
    axes[0].axvline(x=19, color='gray', linestyle='--', linewidth=1)
    axes[0].axvline(x=39, color='gray', linestyle='--', linewidth=1)
    axes[0].set_ylabel("Task A")
    axes[0].set_ylim(0.75, 1)
    axes[0].legend(loc="lower left")
    axes[0].set_xticklabels([])
    
    axes[1].plot(time_B_padded, sgd_B_padded, label="SGD", color=colors['sgd'], alpha=0.8)
    axes[1].plot(time_B_padded, ewc_B_padded, label="EWC", color=colors['ewc'], alpha=0.8)
    axes[1].plot(time_B_padded, l2_B_padded, label="L2", color=colors['l2'], alpha=0.8)
    axes[1].axvline(x=19, color='gray', linestyle='--', linewidth=1)
    axes[1].axvline(x=39, color='gray', linestyle='--', linewidth=1)
    axes[1].set_ylabel("Task B")
    axes[1].set_ylim(0.75, 1)
    axes[1].legend(loc="lower left")
    axes[1].set_xticklabels([])
    
    axes[2].plot(time_C_padded, sgd_C_padded, label="SGD", color=colors['sgd'], alpha=0.8)
    axes[2].plot(time_C_padded, ewc_C_padded, label="EWC", color=colors['ewc'], alpha=0.8)
    axes[2].plot(time_C_padded, l2_C_padded, label="L2", color=colors['l2'], alpha=0.8)
    axes[2].axvline(x=19, color='gray', linestyle='--', linewidth=1)
    axes[2].axvline(x=39, color='gray', linestyle='--', linewidth=1)
    axes[2].set_xlabel("Training time")
    axes[2].set_ylabel("Task C")
    axes[2].set_ylim(0.75, 1)
    axes[2].legend(loc="lower left")
    axes[2].set_xticklabels([])
    
    plt.tight_layout()
    plt.show()

# %%
#Plot results for experiment 2A on permutated MNIST
plot_experiment_2A(epoch_accuracies_SGD, epoch_accuracies_EWC, epoch_accuracies_L2)

# %%
#Run experiment 2B on permutated MNIST 

acc_sgd, acc_ewc = run_experiment_2B(permuted_train_loaders[0:3],permuted_test_loaders[0:3])
# Out:
# Trial 1/1: Learning rate=0.00009, Hidden layer width=1044
# Training on Task 1
# Task 1, Epoch 1/10, SGD Loss: 0.0010
# Task 1, Epoch 1/10, EWC Loss: 0.0009
# Task 1, Epoch 2/10, SGD Loss: 0.0011
# Task 1, Epoch 2/10, EWC Loss: 0.0007
# Task 1, Epoch 3/10, SGD Loss: 0.0009
# Task 1, Epoch 3/10, EWC Loss: 0.0011
# Task 1, Epoch 4/10, SGD Loss: 0.0007
# Task 1, Epoch 4/10, EWC Loss: 0.0005
# Task 1, Epoch 5/10, SGD Loss: 0.0006
# Task 1, Epoch 5/10, EWC Loss: 0.0004
# Task 1, Epoch 6/10, SGD Loss: 0.0004
# Task 1, Epoch 6/10, EWC Loss: 0.0004
# Task 1, Epoch 7/10, SGD Loss: 0.0002
# Task 1, Epoch 7/10, EWC Loss: 0.0004
# Task 1, Epoch 8/10, SGD Loss: 0.0007
# Task 1, Epoch 8/10, EWC Loss: 0.0011
# Task 1, Epoch 9/10, SGD Loss: 0.0004
# Task 1, Epoch 9/10, EWC Loss: 0.0006
# Task 1, Epoch 10/10, SGD Loss: 0.0004
# Task 1, Epoch 10/10, EWC Loss: 0.0003
# Training on Task 2
# Task 2, Epoch 1/10, SGD Loss: 0.0011
# Task 2, Epoch 1/10, EWC Loss: 0.0011
# Task 2, Epoch 2/10, SGD Loss: 0.0010
# Task 2, Epoch 2/10, EWC Loss: 0.0010
# Task 2, Epoch 3/10, SGD Loss: 0.0008
# Task 2, Epoch 3/10, EWC Loss: 0.0007
# Task 2, Epoch 4/10, SGD Loss: 0.0009
# Task 2, Epoch 4/10, EWC Loss: 0.0009
# Task 2, Epoch 5/10, SGD Loss: 0.0008
# Task 2, Epoch 5/10, EWC Loss: 0.0007
# Task 2, Epoch 6/10, SGD Loss: 0.0006
# Task 2, Epoch 6/10, EWC Loss: 0.0006
# Task 2, Epoch 7/10, SGD Loss: 0.0004
# Task 2, Epoch 7/10, EWC Loss: 0.0007
# Task 2, Epoch 8/10, SGD Loss: 0.0008
# Task 2, Epoch 8/10, EWC Loss: 0.0005
# Task 2, Epoch 9/10, SGD Loss: 0.0004
# Task 2, Epoch 9/10, EWC Loss: 0.0005
# Task 2, Epoch 10/10, SGD Loss: 0.0006
# Task 2, Epoch 10/10, EWC Loss: 0.0005
# Training on Task 3
# Task 3, Epoch 1/10, SGD Loss: 0.0012
# Task 3, Epoch 1/10, EWC Loss: 0.0014
# Task 3, Epoch 2/10, SGD Loss: 0.0011
# Task 3, Epoch 2/10, EWC Loss: 0.0010
# Task 3, Epoch 3/10, SGD Loss: 0.0013
# Task 3, Epoch 3/10, EWC Loss: 0.0010
# Task 3, Epoch 4/10, SGD Loss: 0.0009
# Task 3, Epoch 4/10, EWC Loss: 0.0009
# Task 3, Epoch 5/10, SGD Loss: 0.0006
# Task 3, Epoch 5/10, EWC Loss: 0.0005
# Task 3, Epoch 6/10, SGD Loss: 0.0008
# Task 3, Epoch 6/10, EWC Loss: 0.0009
# Task 3, Epoch 7/10, SGD Loss: 0.0009
# Task 3, Epoch 7/10, EWC Loss: 0.0008
# Task 3, Epoch 8/10, SGD Loss: 0.0005
# Task 3, Epoch 8/10, EWC Loss: 0.0005
# Task 3, Epoch 9/10, SGD Loss: 0.0006
# Task 3, Epoch 9/10, EWC Loss: 0.0005
# Task 3, Epoch 10/10, SGD Loss: 0.0005
# Task 3, Epoch 10/10, EWC Loss: 0.0004
# (None, None)

# %%
#Plot results for experiment 2B on permutated MNIST

num_tasks = len(permuted_test_loaders[0:3])
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_tasks + 1), acc_sgd, label='SGD+dropout', marker='o', color='blue')
plt.plot(range(1, num_tasks + 1), acc_ewc, label='EWC', marker='o', color='red')
plt.axhline(y=1.0, linestyle='--', color='black', label='Single Task Performance')
plt.xlabel('Number of Tasks')
plt.ylabel('Fraction Correct')
plt.legend()
plt.title('Fraction Correct vs Number of Tasks')
plt.grid(True)
plt.show()
